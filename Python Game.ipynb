# %%
choice = input('''
You wake up stranded on a foggy island. What do you do?
Answer by typing in: Option 1, Option2, or Option 3.

Option 1: Swim back into the ocean to try to find home.

Option 2: Climb and sleep in a nearby tree.

Option 3: Check out what you have with you and do something with them.


''')

if choice == 'Option 1':
    print(" \n1) You swam back into the ocean. You dived into a rock. GAME OVER!!!")
elif choice == 'Option 3':
    print(" \nGreat! So you have a flimsy survival saw, a pocketknife, a single waterproof match, and a plastic bag.\n Now you made a fire and a quick shelter. Hooray you are still alive! Yay!")
else:
    print(" \n Ok, you hid on a tree until morning. You got hyperthermia and went X_X. GAME OVER!!!")
    
#IF/ELSE STATEMENT 1
    
if choice == 'Option 3' :
    
    choice_two = input ('''
    Hurrah! You are alive. Now you have three options of what to do."
    
    Option 1: Go hunting with a sharp stick.
    
    Option 2: Start a fire.
    
    Option 3: Build a shelter.
    
    
    ''')
else:
    print("")
    
#IF/ELSE STATEMENT 2. THE EMPTY PRINT() IS THERE OR ELSE THE CELL WILL RUN INFINITELY.
    
if choice_two == 'Option 1':
    
    print("You ran into a bear. Mr. Bear dosen't like strangers. So, he ate you. GAME OVER!!!")

elif choice_two == 'Option 2':
    
    print("Yay! You started a fire. Now you are warm and dry. But wait! You only have 245 minutes till sunset!\nWhat will you do?")
else:
    print("Smart choice, but bad luck got you. You built a shelter and decided to see if it was comfy.\nYou went in a knocked a stick and the  shelter collasped on you. OOF! GAME OVER!")
    
#IF/ELSE STATEMENT 3

if choice_two == 'Option 2':
    
    choice_three = input ('''
    
    Here are your options of what you can do before the creepy crawlies come out.
    
    Option 1: Turn your fire into a bonfire. It's going to be BIG!
    
    Option 2: Build a quick shelter.
    
    Option 3: Stay beside your fire to stay warm.
    
    
    ''')
else:
    print("")
    
#IF/ELSE STATEMENT 4

if choice_three == 'Option 1':
    
    print("You managed to make a bonfire. But, you slipped and fell into the fire. GAME OVER!!!")
    
elif choice_three == 'Option 2':
    
    print("You built a quick shelter. Your fire died, but the shelter and your fire combined kept you alive.")

else:
    print("Your fire died halfway through the night. Hyperthermia got you! GAME OVER!!!")
    
# IF ELSE STATEMENT 5

if choice_three == 'Option 2':
    
    choice_four = input ("""
    
    You are getting thirsty and hungry.
    
    Option 1: Try to find some food.
    
    Option 2: Try to find a good source of water.
    
    """)

else:
    print("")
    
#IF/ELSE STATEMENT 6

if choice _four == 'Option 1':
    print("")
    
else:
    print("")
    
    
    
    
    
def choice_one ():
    
    print('''
    
    Here are your choices of trying to get some food:
    
    
    
    
    ''')
# Out:
#   File "<ipython-input-1-ecfbbb2a822a>", line 102
#     if choice _four == 'Option 1':
#                   ^
# SyntaxError: invalid syntax

# %%
#COOL END OF GAME SNOWFLAKE REWARD KIND OF THING. SURVIVE THE ISLAND ALL THE WAY AND YOU GET TO SEE MY AMAZING CREATION!

def cool_snowflake_thingy ():
    
    import turtle
    
    turtle.pencolor("blue")
    
    for i in range (40):
        turtle.hideturtle()
        turtle.forward(100)
        turtle.right(80)
        turtle.forward(200)
        turtle.right(30)

# %%
def
