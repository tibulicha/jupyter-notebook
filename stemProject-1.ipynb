# %%
import turtle

turtle.forward(150)
turtle.left(30)
turtle.forward(50)
turtle.right(90)
print ("--------")
print("| | | | |")
print("| | | | |")
# Out:
# ------------------
# |

# %%
dir(turtle)
# Out:
# ['Canvas',
#  'Pen',
#  'RawPen',
#  'RawTurtle',
#  'Screen',
#  'ScrolledCanvas',
#  'Shape',
#  'TK',
#  'TNavigator',
#  'TPen',
#  'Tbuffer',
#  'Terminator',
#  'Turtle',
#  'TurtleGraphicsError',
#  'TurtleScreen',
#  'TurtleScreenBase',
#  'Vec2D',
#  '_CFG',
#  '_LANGUAGE',
#  '_Root',
#  '_Screen',
#  '_TurtleImage',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__forwardmethods',
#  '__func_body',
#  '__loader__',
#  '__methodDict',
#  '__methods',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stringBody',
#  '_alias_list',
#  '_make_global_funcs',
#  '_screen_docrevise',
#  '_tg_classes',
#  '_tg_screen_functions',
#  '_tg_turtle_functions',
#  '_tg_utilities',
#  '_turtle_docrevise',
#  '_ver',
#  'addshape',
#  'back',
#  'backward',
#  'begin_fill',
#  'begin_poly',
#  'bgcolor',
#  'bgpic',
#  'bk',
#  'bye',
#  'circle',
#  'clear',
#  'clearscreen',
#  'clearstamp',
#  'clearstamps',
#  'clone',
#  'color',
# ...
